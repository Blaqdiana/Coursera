# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * List data science languages
# * List data science libraries
# * A Table of some Data Science tools
# * Arithmetic Expression

# %% [markdown]
# ### List data science languages
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Structured query language (SQL)
# 4. Julia
# 5. Java
# 6. Scala

# %% [markdown]
# ### List data science libraries
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Scipy
# 7. TensorFlow

# %% [markdown]
# ### A Table of some Data Science tools
# | Data Science Tools |
# |--------------------|
# | Jupiter Notebook   |
# | RStudio            |
# | Anaconda           |
# | Visual Studio Code |

# %% [markdown]
# ### Arithmetic Expression
# Below are a few examples of evaluating arithmetic expressions in Python:
# Addition   - 5 + 5
# Subtraction	- 10 - 7
# Multiplication	- 3 * 3
# Division	- 8 / 4
# Modulo	- 3 % 2
# Power	- 2 ** 4

# %%
# This a simple arithmetic expression to mutiply then add integers
print(f" Result: {(3*4)+5}")
# Out:
#  Result: 17

# %%
# This expression will convert 200 minutes to hours by diving by 60
print(f"200 / 60 will result to: {200 / 60} hours")
# Out:
# 200 / 60 will result to: 3.3333333333333335 hours

# %% [markdown]
# ## Author
# Diana Ofili
